# %% [markdown]
# <h1 style="text-align:center; font-size:36px; font-weight:bold;">Comprehensive Data-Driven Analysis NBA Players</h1>

# %% [markdown]
# <h3 style="text-align:center; font-size:22px; font-weight:bold; font-family: 'Arial', sans-serif; color:#BBBBBB;">
#     Created with passion by: Hirad Pejman, Mehran Mahdiani, Raana Fatahi, Sama Zohari 🚀🔥
# </h3>

# %% [markdown]
# <div style="text-align:center;">
#     <img src="project_cover.png" alt="Project Cover" style="width:60%; border-radius:10px;">
# </div>

# %% [markdown]
# # import libraries

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import csv
import re
import time
import math
from datetime import datetime

# %% [markdown]
# # aval az hame bayad list e baikon haro be tafkik har fasl dar biarim darbiarim

# %%
class NBAScraper:
    """
    A class for scraping NBA player statistics from Basketball Reference.
    """
    BASE_URL = "https://www.basketball-reference.com"
    HEADERS = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9",
    }
    
    def __init__(self):
        """
        Initializes the scraper and finds the most recent "Player Stats" page.
        """
        self.current_page = self.get_player_stats_url()
        self.year_links = []
        self.player_links = []
    
    def get_player_stats_url(self):
        """
        Extracts the URL of the "Player Stats" page from the main site.
        """
        response = requests.get(self.BASE_URL, headers=self.HEADERS)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find the "Player Stats" link
        for link in soup.find_all('a'):
            if link.text == 'Player Stats':
                return f"{self.BASE_URL}{link['href']}"
        
        raise ValueError("Player Stats page not found")
    
    def get_yearly_links(self, num_years=5):
        """
        Retrieves links for the past `num_years` seasons.
        """
        current_url = self.current_page
        
        for _ in range(num_years):
            response = requests.get(current_url, headers=self.HEADERS)
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Find the "Previous Season" button to get past season links
            prev_button = soup.find(class_="button2 prev")
            if prev_button and 'href' in prev_button.attrs:
                current_url = f"{self.BASE_URL}{prev_button['href']}"
                self.year_links.append(current_url)
            else:
                break  # Stop if no previous season link is found
    
    def extract_player_links(self):
        """
        Extracts player profile links from the stored yearly season pages.
        """
        for link in self.year_links:
            response = requests.get(link, headers=self.HEADERS)
            soup = BeautifulSoup(response.content, 'html.parser')
            
            table_rows = soup.select('table.stats_table tbody tr')
            player_per_year = []
            
            for row in table_rows:
                player_cell = row.find('td', class_='left')
                if player_cell and player_cell.find('a'):
                    href = player_cell.find('a')['href']
                    player_per_year.append(f"{self.BASE_URL}{href}")
            
            self.player_links.append(self.remove_duplicates(player_per_year))
    
    @staticmethod
    def remove_duplicates(lst):
        """
        Removes duplicate URLs from the list while preserving order.
        """
        seen = set()
        return [x for x in lst if not (x in seen or seen.add(x))]
    
    def process_data(self):
        """
        Runs the complete scraping process and refines extracted data.
        """
        self.get_yearly_links()
        self.extract_player_links()
        
        # Adjust the extracted data based on manual filtering (removing last few entries for some years)
        if len(self.player_links) >= 5:
            self.player_links[1] = self.player_links[1][:-2]  # Trim last 2 players for 2023
            self.player_links[2] = self.player_links[2][:-1]  # Trim last player for 2022
            self.player_links[4] = self.player_links[4][:-1]  # Trim last player for 2020
    
    def display_results(self):
        """
        Prints the number of players extracted per year.
        """
        years = [2024, 2023, 2022, 2021, 2020]
        for i, year in enumerate(years):
            print(f"{year}: {len(self.player_links[i])} players")
    
# Run the scraper
scraper = NBAScraper()
scraper.process_data()
scraper.display_results()
# Out:
# 2024: 572 players
# 2023: 539 players
# 2022: 605 players
# 2021: 540 players
# 2020: 529 players

# %%
## khob ma midhnunim tanha chiazyi k mikhaym az har fasl inas: 1- 50 taye aval, 2- nafarate team 2 ghahreman, 3- azaye list e michael jordan trophy
## midhunim azaye list e michael jordan trophy ghatan too 650 taye aval hastan tanha tarsi ke darim ine ke adamaye team e ghahreman nakhan bashan 
## bara hamin mitunim nehine konim!!

# %%
## aval lazem darim ta bbinim ch team hayi dar che sali ghahreman shodan!!!

# %% [markdown]
# ## Champ Team Lists

# %%
class BasketballChampionsScraper:
    def __init__(self, url):
        self.url = url
        self.soup = None
        self.season_data = []
        self.filtered_years = ['2019-20', '2020-21', '2021-22', '2022-23', '2023-24']
        self.df = None
        self.champ_teams = []

    def fetch_data(self):
        """Sends a request to the webpage and parses the HTML content."""
        response = requests.get(self.url)
        if response.status_code == 200:
            self.soup = BeautifulSoup(response.content, 'html.parser')
        else:
            raise Exception(f"Failed to fetch data. Status Code: {response.status_code}")

    def extract_data(self):
        """Extracts champion team data from the HTML content."""
        stats_table = self.soup.find('table', {'id': 'stats'})
        if not stats_table:
            raise Exception("Could not find the stats table on the page.")

        rows = stats_table.find_all('tr')
        for row in rows:
            cols = row.find_all('td')
            if cols:
                season = row.find('th').text.strip()
                champion_cell = cols[1].find('a')

                if champion_cell:
                    champion = champion_cell.text.strip()
                    team_abbr = champion_cell['href'].split('/')[-2]
                    season_year = str(int(season[:4]) + 1)  # Adjusting year by +1
                    champion_link = f"https://www.basketball-reference.com/teams/{team_abbr}/{season_year}.html"
                else:
                    champion = cols[1].text.strip()
                    champion_link = None

                self.season_data.append({'Season': season, 'Champion': champion, 'Champion Link': champion_link})

    def filter_data(self):
        """Filters the data for specific seasons."""
        self.df = pd.DataFrame(self.season_data)
        self.df = self.df[self.df['Season'].isin(self.filtered_years)]
        self.champ_teams = self.df['Champion Link'].dropna().tolist()

    def save_to_csv(self, filename='Champ_of_each_season_with_links.csv'):
        """Saves the filtered data to a CSV file."""
        if self.df is not None:
            self.df.to_csv(filename, index=False)

    def display_results(self):
        """Prints the filtered DataFrame and champion team links."""
        print(self.df)
        print(self.champ_teams)

    def run(self):
        """Executes all steps in sequence."""
        self.fetch_data()
        self.extract_data()
        self.filter_data()
        self.save_to_csv()
        self.display_results()

# Running the scraper
scraper = BasketballChampionsScraper('https://www.basketball-reference.com/leagues/')
scraper.run()
# Out:
#     Season               Champion  \
# 1  2023-24         Boston Celtics
# 2  2022-23         Denver Nuggets
# 3  2021-22  Golden State Warriors
# 4  2020-21        Milwaukee Bucks
# 5  2019-20     Los Angeles Lakers
#
#                                        Champion Link
# 1  https://www.basketball-reference.com/teams/BOS...
# 2  https://www.basketball-reference.com/teams/DEN...
# 3  https://www.basketball-reference.com/teams/GSW...
# 4  https://www.basketball-reference.com/teams/MIL...
# 5  https://www.basketball-reference.com/teams/LAL...
# ['https://www.basketball-reference.com/teams/BOS/2024.html', 'https://www.basketball-reference.com/teams/DEN/2023.html', 'https://www.basketball-reference.com/teams/GSW/2022.html', 'https://www.basketball-reference.com/teams/MIL/2021.html', 'https://www.basketball-reference.com/teams/LAL/2020.html']

# %% [markdown]
# ## Champ team Players Link!

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# List of URLs for scraping
urls = champ_teams  

# HTTP headers for requests
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

def scrape_totals_table(url):
    """Scrapes the 'Totals' table from the given URL and saves it as a CSV file."""
    response = requests.get(url, headers=HEADERS)
    if response.status_code != 200:
        print(f"Failed to fetch URL: {url}. Status code: {response.status_code}")
        return

    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the "Totals" table
    table = next((t for t in soup.find_all('table') if t.find('thead') and 'Totals' in t.text), None)
    if not table:
        print(f"Table containing 'Totals' not found for {url}.")
        return

    # Extract headers
    table_headers = [th.text.strip() for th in table.find('thead').find_all('th') if th.text.strip()]

    # Extract rows
    rows = table.find('tbody').find_all('tr')
    data = []
    for row in rows:
        if row.get('class') and 'thead' in row.get('class'):
            continue  # Skip internal header rows
        row_data = [td.text.strip() for td in row.find_all('td')]

        # Ensure row_data matches header length
        row_data = (row_data + [None] * len(table_headers))[:len(table_headers)]

        data.append(row_data)

    # Create DataFrame and save it as CSV
    team_year = url.split('/')[-1].replace('.html', '')
    output_file_path = f'{team_year}_Totals.csv'
    pd.DataFrame(data, columns=table_headers).to_csv(output_file_path, index=False, encoding='utf-8')
    print(f"Data saved to {output_file_path}")

def scrape_champ_player_links():
    """Scrapes player profile links from the champion teams' pages."""
    champ_player_links = {}

    for url in urls:
        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Failed to fetch {url}. Status code: {response.status_code}")
            continue

        soup = BeautifulSoup(response.content, 'html.parser')
        table = soup.find('tbody')
        if not table:
            print(f"No player data found for {url}")
            continue

        player_links = [
            'https://www.basketball-reference.com' + a['href']
            for a in table.find_all('a') if 'players' in a['href']
        ]

        team_year = url.split('/')[-1].replace('.html', '')
        champ_player_links[team_year] = player_links

    return champ_player_links

# Scrape player links
champ_player_links = scrape_champ_player_links()

# Example: Print links for 2024 champion players
print(champ_player_links.get('2024', []))
# Out:
# ['https://www.basketball-reference.com/players/b/bantoda01.html', 'https://www.basketball-reference.com/players/b/brissos01.html', 'https://www.basketball-reference.com/players/b/brownja02.html', 'https://www.basketball-reference.com/players/d/davisjd01.html', 'https://www.basketball-reference.com/players/h/hausesa01.html', 'https://www.basketball-reference.com/players/h/holidjr01.html', 'https://www.basketball-reference.com/players/h/horfoal01.html', 'https://www.basketball-reference.com/players/k/kornelu01.html', 'https://www.basketball-reference.com/players/m/mykhasv01.html', 'https://www.basketball-reference.com/players/p/peterdr01.html', 'https://www.basketball-reference.com/players/p/porzikr01.html', 'https://www.basketball-reference.com/players/p/pritcpa01.html', 'https://www.basketball-reference.com/players/q/quetane01.html', 'https://www.basketball-reference.com/players/s/sprinja01.html', 'https://www.basketball-reference.com/players/s/stevela01.html', 'https://www.basketball-reference.com/players/t/tatumja01.html', 'https://www.basketball-reference.com/players/t/tillmxa01.html', 'https://www.basketball-reference.com/players/w/walshjo01.html', 'https://www.basketball-reference.com/players/w/whitede01.html']

# %%
## Clean Data

# %%
# Extracting the first 60 player links from each year using NBAScraper data
links_60 = {year: scraper.player_links[i][:60] for i, year in enumerate([2024, 2023, 2022, 2021, 2020])}

# Combining all the first 60 player links
all_60players = sum(links_60.values(), [])

# Combining with champion team player links
champion_links = [
    champ_player_links.get(str(year), []) for year in years
]
all_links = all_60players + sum(champion_links, [])

# Removing duplicate links
unique_players_links = list(set(all_links))

# Final result
print(len(unique_players_links))
# Out:
# 193

# %%
## natije migirm kole bazikon hayi ke ma bahashoon kar darim 193 ta bazikon haatsand!

# %%
## hala shoro be scrap kardane in ha mikonim!
## in code beyne hardota bazikon 2s time sleep darad va bad azinke har 50 ta ro scrap mikone 20s time sleep mide!

# %%
class PlayerScraper:
    def __init__(self, url):
        self.url = url
        self.soup = None
        self.data = {}

    def fetch_data(self):
        headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}
        response = requests.get(self.url, headers=headers)
        if response.status_code == 200:
            self.soup = BeautifulSoup(response.text, 'html.parser')
        else:
            raise Exception(f"Failed to fetch data. Status code: {response.status_code}")

    def extract_name_and_id(self):
        name_tag = self.soup.find('h1').find('span')
        self.data['Name'] = name_tag.text.strip() if name_tag else "Not Listed"
        self.data['P_ID'] = self.url.split('/')[-1].replace('.html', '')

    def extract_team_and_id(self):
        team_tag = self.soup.find('strong', string='Team')
        self.data['Team'] = team_tag.find_next('a').text.strip() if team_tag else "Not Listed"
        team_link = team_tag.find_next('a')['href'] if team_tag and team_tag.find_next('a') else "No link available"
        self.data['T_ID'] = team_link.split('/')[-2] if team_link != "No link available" else "Not Listed"

    def extract_physical_stats(self):
        height, weight = "None", "None"
        for tag in self.soup.find_all('p'):
            text = tag.get_text(strip=True)
            match = re.search(r'\((\d+)cm,\s*(\d+)kg\)', text)
            if match:
                height, weight = int(match.group(1)), int(match.group(2))
                break
        self.data['H(cm)'] = height
        self.data['W(Kg)'] = weight

    def extract_age(self):
        age_tag = self.soup.find('span', {'id': 'necro-birth'})
        if age_tag:
            birth_date = age_tag.get('data-birth')
            if birth_date:
                birth_year = int(birth_date.split('-')[0])
                current_year = datetime.now().year
                self.data['Age'] = current_year - birth_year
                return
        self.data['Age'] = "None"

    def extract_experience(self):
        experience_tag = self.soup.find('strong', string='Experience:')
        experience_years = experience_tag.next_sibling.strip() if experience_tag else "0"
        experience_years = experience_years.replace('\xa0', ' ').strip()  # Remove nbsp
        if "years" in experience_years.lower():
            experience_years = experience_years.split()[0]
        self.data['Exp_Yrs'] = int(experience_years) if experience_years.isdigit() else 0

    def extract_entry_age(self):
        age = self.data.get('Age', "None")
        experience = self.data.get('Exp_Yrs', 0)
        if age != "None" and experience != "None" and isinstance(age, int) and isinstance(experience, int):
            self.data['Entry_Age'] = age - experience
        else:
            self.data['Entry_Age'] = "None"

class BasicPlayerScraper:
    def __init__(self, url):
        self.scraper = PlayerScraper(url)

    def scrape_basic_info(self):
        self.scraper.fetch_data()
        self.scraper.extract_name_and_id()
        self.scraper.extract_team_and_id()
        self.scraper.extract_physical_stats()
        self.scraper.extract_age()
        self.scraper.extract_experience()
        self.scraper.extract_entry_age()
        return {
            'Name': self.scraper.data.get('Name', "None"),
            'P_ID': self.scraper.data.get('P_ID', "None"),
            'Team': self.scraper.data.get('Team', "None"),
            'T_ID': self.scraper.data.get('T_ID', "None"),
            'H(cm)': self.scraper.data.get('H(cm)', "None"),
            'W(Kg)': self.scraper.data.get('W(Kg)', "None"),
            'Entry_Age': self.scraper.data.get('Entry_Age', "None"),
        }

def process_player_links(player_links, initial_sleep_time=2, max_retries=5):
    players_data = []
    sleep_time = initial_sleep_time

    for index, url in enumerate(player_links):
        retries = 0
        while retries < max_retries:
            try:
                print(f"Processing {index + 1}/{len(player_links)}: {url}")
                scraper = BasicPlayerScraper(url)
                player_data = scraper.scrape_basic_info()
                players_data.append(player_data)
                time.sleep(sleep_time)

                # Check if we've processed 50 players, then pause for 40 seconds
                if (index + 1) % 50 == 0:
                    print("Pausing for 20 seconds...")
                    time.sleep(20)
                
                break
            except Exception as e:
                if "429" in str(e):
                    retries += 1
                    sleep_time += 2  # Increase sleep time dynamically
                    print(f"429 Too Many Requests. Retrying {retries}/{max_retries} after {sleep_time} seconds...")
                    time.sleep(sleep_time)
                else:
                    print(f"Error processing {url}: {e}")
                    break

    # Save to CSV
    file_name = "players_data.csv"
    with open(file_name, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Name', 'P_ID', 'Team', 'T_ID', 'H(cm)', 'W(Kg)', 'Entry_Age'])
        writer.writerows([[p['Name'], p['P_ID'], p['Team'], p['T_ID'], p['H(cm)'], p['W(Kg)'], p['Entry_Age']] for p in players_data])

    print(f"Data saved to {file_name}")
    return players_data



process_player_links(unique_players_links)
# Out:
# Processing 1/193: https://www.basketball-reference.com/players/a/aytonde01.html
# Processing 2/193: https://www.basketball-reference.com/players/s/simonan01.html
# Processing 3/193: https://www.basketball-reference.com/players/m/mykhasv01.html
# Processing 4/193: https://www.basketball-reference.com/players/g/georgpa01.html
# Processing 5/193: https://www.basketball-reference.com/players/o/oubreke01.html
# Processing 6/193: https://www.basketball-reference.com/players/h/howardw01.html
# Processing 7/193: https://www.basketball-reference.com/players/h/hardeja01.html
# Processing 8/193: https://www.basketball-reference.com/players/w/whiteha01.html
# Processing 9/193: https://www.basketball-reference.com/players/k/kornelu01.html
# Processing 10/193: https://www.basketball-reference.com/players/b/butleji01.html
# Processing 11/193: https://www.basketball-reference.com/players/i/ingrabr01.html
# Processing 12/193: https://www.basketball-reference.com/players/c/craigto01.html
# Processing 13/193: https://www.basketball-reference.com/players/l/lowryky01.html
# Processing 14/193: https://www.basketball-reference.com/players/p/paulch01.html
# Processing 15/193: https://www.basketball-reference.com/players/h/holmgch01.html
# Processing 16/193: https://www.basketball-reference.com/players/t/toscaju01.html
# Processing 17/193: https://www.basketball-reference.com/players/b/bantoda01.html
# Processing 18/193: https://www.basketball-reference.com/players/r/randlju01.html
# Processing 19/193: https://www.basketball-reference.com/players/j/jacksju01.html
# Processing 20/193: https://www.basketball-reference.com/players/m/millebr02.html
# Processing 21/193: https://www.basketball-reference.com/players/t/trentga02.html
# Processing 22/193: https://www.basketball-reference.com/players/g/gallida01.html
# Processing 23/193: https://www.basketball-reference.com/players/w/whitede01.html
# Processing 24/193: https://www.basketball-reference.com/players/p/porzikr01.html
# Processing 25/193: https://www.basketball-reference.com/players/b/bradlav01.html
# Processing 26/193: https://www.basketball-reference.com/players/q/quetane01.html
# Processing 27/193: https://www.basketball-reference.com/players/r/reedda01.html
# Processing 28/193: https://www.basketball-reference.com/players/m/maxeyty01.html
# Processing 29/193: https://www.basketball-reference.com/players/b/barneha02.html
# Processing 30/193: https://www.basketball-reference.com/players/t/tatumja01.html
# Processing 31/193: https://www.basketball-reference.com/players/t/teaguje01.html
# Processing 32/193: https://www.basketball-reference.com/players/j/jokicni01.html
# Processing 33/193: https://www.basketball-reference.com/players/m/murraja01.html
# Processing 34/193: https://www.basketball-reference.com/players/w/westbru01.html
# Processing 35/193: https://www.basketball-reference.com/players/d/divindo01.html
# Processing 36/193: https://www.basketball-reference.com/players/h/harrijo01.html
# Processing 37/193: https://www.basketball-reference.com/players/c/cookqu01.html
# Processing 38/193: https://www.basketball-reference.com/players/k/kurucro01.html
# Processing 39/193: https://www.basketball-reference.com/players/w/woodch01.html
# Processing 40/193: https://www.basketball-reference.com/players/h/hieldbu01.html
# Processing 41/193: https://www.basketball-reference.com/players/s/schrode01.html
# Processing 42/193: https://www.basketball-reference.com/players/d/davisjd01.html
# Processing 43/193: https://www.basketball-reference.com/players/j/jacksja02.html
# Processing 44/193: https://www.basketball-reference.com/players/c/cancavl01.html
# Processing 45/193: https://www.basketball-reference.com/players/v/vucevni01.html
# Processing 46/193: https://www.basketball-reference.com/players/g/greenja05.html
# Processing 47/193: https://www.basketball-reference.com/players/r/roziete01.html
# Processing 48/193: https://www.basketball-reference.com/players/p/peterdr01.html
# Processing 49/193: https://www.basketball-reference.com/players/s/stevela01.html
# Processing 50/193: https://www.basketball-reference.com/players/s/siakapa01.html
# Pausing for 20 seconds...
# Processing 51/193: https://www.basketball-reference.com/players/g/goberru01.html
# Processing 52/193: https://www.basketball-reference.com/players/b/brownja02.html
# Processing 53/193: https://www.basketball-reference.com/players/b/bryanel01.html
# Processing 54/193: https://www.basketball-reference.com/players/b/beysa01.html
# Processing 55/193: https://www.basketball-reference.com/players/a/allenja01.html
# Processing 56/193: https://www.basketball-reference.com/players/m/middlkh01.html
# Processing 57/193: https://www.basketball-reference.com/players/m/mobleev01.html
# Processing 58/193: https://www.basketball-reference.com/players/b/braunch01.html
# Processing 59/193: https://www.basketball-reference.com/players/e/embiijo01.html
# Processing 60/193: https://www.basketball-reference.com/players/c/carusal01.html
# Processing 61/193: https://www.basketball-reference.com/players/t/tuckepj01.html
# Processing 62/193: https://www.basketball-reference.com/players/v/vassede01.html
# Processing 63/193: https://www.basketball-reference.com/players/w/wembavi01.html
# Processing 64/193: https://www.basketball-reference.com/players/t/thompkl01.html
# Processing 65/193: https://www.basketball-reference.com/players/b/bridgmi02.html
# Processing 66/193: https://www.basketball-reference.com/players/w/weathqu01.html
# Processing 67/193: https://www.basketball-reference.com/players/a/adebaba01.html
# Processing 68/193: https://www.basketball-reference.com/players/g/greenda02.html
# Processing 69/193: https://www.basketball-reference.com/players/b/bjeline01.html
# Processing 70/193: https://www.basketball-reference.com/players/p/powelno01.html
# Processing 71/193: https://www.basketball-reference.com/players/p/pritcpa01.html
# Processing 72/193: https://www.basketball-reference.com/players/i/iguodan01.html
# Processing 73/193: https://www.basketball-reference.com/players/c/cunnica01.html
# Processing 74/193: https://www.basketball-reference.com/players/m/merrisa01.html
# Processing 75/193: https://www.basketball-reference.com/players/h/harremo01.html
# Processing 76/193: https://www.basketball-reference.com/players/w/waitedi01.html
# Processing 77/193: https://www.basketball-reference.com/players/p/poolejo01.html
# Processing 78/193: https://www.basketball-reference.com/players/s/sengual01.html
# Processing 79/193: https://www.basketball-reference.com/players/l/lopezbr01.html
# Processing 80/193: https://www.basketball-reference.com/players/h/hardati02.html
# Processing 81/193: https://www.basketball-reference.com/players/d/doncilu01.html
# Processing 82/193: https://www.basketball-reference.com/players/c/curryst01.html
# Processing 83/193: https://www.basketball-reference.com/players/l/lavinza01.html
# Processing 84/193: https://www.basketball-reference.com/players/a/adamsja01.html
# Processing 85/193: https://www.basketball-reference.com/players/n/norveza01.html
# Processing 86/193: https://www.basketball-reference.com/players/g/grahade01.html
# Processing 87/193: https://www.basketball-reference.com/players/w/willija06.html
# Processing 88/193: https://www.basketball-reference.com/players/c/collijo01.html
# Processing 89/193: https://www.basketball-reference.com/players/d/diakima01.html
# Processing 90/193: https://www.basketball-reference.com/players/w/watsope01.html
# Processing 91/193: https://www.basketball-reference.com/players/s/smithjr01.html
# Processing 92/193: https://www.basketball-reference.com/players/a/antetgi01.html
# Processing 93/193: https://www.basketball-reference.com/players/m/murrade01.html
# Processing 94/193: https://www.basketball-reference.com/players/g/garlada01.html
# Processing 95/193: https://www.basketball-reference.com/players/d/danietr01.html
# Processing 96/193: https://www.basketball-reference.com/players/b/banede01.html
# Processing 97/193: https://www.basketball-reference.com/players/n/nnajize01.html
# Processing 98/193: https://www.basketball-reference.com/players/r/rondora01.html
# Processing 99/193: https://www.basketball-reference.com/players/r/russeda01.html
# Processing 100/193: https://www.basketball-reference.com/players/c/clarkjo01.html
# Pausing for 20 seconds...
# Processing 101/193: https://www.basketball-reference.com/players/d/duranke01.html
# Processing 102/193: https://www.basketball-reference.com/players/y/youngtr01.html
# Processing 103/193: https://www.basketball-reference.com/players/l/leonaka01.html
# Processing 104/193: https://www.basketball-reference.com/players/w/walkeke02.html
# Processing 105/193: https://www.basketball-reference.com/players/p/portibo01.html
# Processing 106/193: https://www.basketball-reference.com/players/l/looneke01.html
# Processing 107/193: https://www.basketball-reference.com/players/k/kuminjo01.html
# Processing 108/193: https://www.basketball-reference.com/players/h/herroty01.html
# Processing 109/193: https://www.basketball-reference.com/players/w/walshjo01.html
# Processing 110/193: https://www.basketball-reference.com/players/b/brownbr01.html
# Processing 111/193: https://www.basketball-reference.com/players/j/jordade01.html
# Processing 112/193: https://www.basketball-reference.com/players/m/moranja01.html
# Processing 113/193: https://www.basketball-reference.com/players/t/tillmxa01.html
# Processing 114/193: https://www.basketball-reference.com/players/s/sextoco01.html
# Processing 115/193: https://www.basketball-reference.com/players/c/chiozch01.html
# Processing 116/193: https://www.basketball-reference.com/players/t/townska01.html
# Processing 117/193: https://www.basketball-reference.com/players/h/halibty01.html
# Processing 118/193: https://www.basketball-reference.com/players/b/brogdma01.html
# Processing 119/193: https://www.basketball-reference.com/players/b/brookdi01.html
# Processing 120/193: https://www.basketball-reference.com/players/h/hylanbo01.html
# Processing 121/193: https://www.basketball-reference.com/players/c/caldwke01.html
# Processing 122/193: https://www.basketball-reference.com/players/d/dudleja01.html
# Processing 123/193: https://www.basketball-reference.com/players/g/gilgesh01.html
# Processing 124/193: https://www.basketball-reference.com/players/b/bogdabo02.html
# Processing 125/193: https://www.basketball-reference.com/players/m/mccolcj01.html
# Processing 126/193: https://www.basketball-reference.com/players/p/porteot01.html
# Processing 127/193: https://www.basketball-reference.com/players/f/foxde01.html
# Processing 128/193: https://www.basketball-reference.com/players/w/warretj01.html
# Processing 129/193: https://www.basketball-reference.com/players/m/mcgeeja01.html
# Processing 130/193: https://www.basketball-reference.com/players/k/kuzmaky01.html
# Processing 131/193: https://www.basketball-reference.com/players/v/valanjo01.html
# Processing 132/193: https://www.basketball-reference.com/players/m/mitchdo01.html
# Processing 133/193: https://www.basketball-reference.com/players/a/antetko01.html
# Processing 134/193: https://www.basketball-reference.com/players/s/sprinja01.html
# Processing 135/193: https://www.basketball-reference.com/players/v/vanvlfr01.html
# Processing 136/193: https://www.basketball-reference.com/players/h/hortota01.html
# Processing 137/193: https://www.basketball-reference.com/players/d/dinwisp01.html
# Processing 138/193: https://www.basketball-reference.com/players/w/willizi01.html
# Processing 139/193: https://www.basketball-reference.com/players/m/morrima02.html
# Processing 140/193: https://www.basketball-reference.com/players/b/brunsja01.html
# Processing 141/193: https://www.basketball-reference.com/players/h/horfoal01.html
# Processing 142/193: https://www.basketball-reference.com/players/e/edwaran01.html
# Processing 143/193: https://www.basketball-reference.com/players/w/wiggian01.html
# Processing 144/193: https://www.basketball-reference.com/players/h/harrito02.html
# Processing 145/193: https://www.basketball-reference.com/players/a/antetth01.html
# Processing 146/193: https://www.basketball-reference.com/players/t/turnemy01.html
# Processing 147/193: https://www.basketball-reference.com/players/s/sabondo01.html
# Processing 148/193: https://www.basketball-reference.com/players/b/brissos01.html
# Processing 149/193: https://www.basketball-reference.com/players/b/ballla01.html
# Processing 150/193: https://www.basketball-reference.com/players/f/forbebr01.html
# Pausing for 20 seconds...
# Processing 151/193: https://www.basketball-reference.com/players/g/greenje02.html
# Processing 152/193: https://www.basketball-reference.com/players/t/toupaax01.html
# Processing 153/193: https://www.basketball-reference.com/players/a/augusdj01.html
# Processing 154/193: https://www.basketball-reference.com/players/w/wagnefr01.html
# Processing 155/193: https://www.basketball-reference.com/players/d/derozde01.html
# Processing 156/193: https://www.basketball-reference.com/players/g/grantje01.html
# Processing 157/193: https://www.basketball-reference.com/players/g/greendr01.html
# Processing 158/193: https://www.basketball-reference.com/players/c/cacokde01.html
# Processing 159/193: https://www.basketball-reference.com/players/j/johnske04.html
# Processing 160/193: https://www.basketball-reference.com/players/f/fournev01.html
# Processing 161/193: https://www.basketball-reference.com/players/h/holidjr01.html
# Processing 162/193: https://www.basketball-reference.com/players/w/willilo02.html
# Processing 163/193: https://www.basketball-reference.com/players/l/leeda03.html
# Processing 164/193: https://www.basketball-reference.com/players/j/jacksre01.html
# Processing 165/193: https://www.basketball-reference.com/players/d/dowtije01.html
# Processing 166/193: https://www.basketball-reference.com/players/w/wilsodj01.html
# Processing 167/193: https://www.basketball-reference.com/players/r/reaveau01.html
# Processing 168/193: https://www.basketball-reference.com/players/p/paytoga02.html
# Processing 169/193: https://www.basketball-reference.com/players/g/gordoaa01.html
# Processing 170/193: https://www.basketball-reference.com/players/b/bookede01.html
# Processing 171/193: https://www.basketball-reference.com/players/b/banchpa01.html
# Processing 172/193: https://www.basketball-reference.com/players/g/giddejo01.html
# Processing 173/193: https://www.basketball-reference.com/players/m/morrima03.html
# Processing 174/193: https://www.basketball-reference.com/players/b/bogdabo01.html
# Processing 175/193: https://www.basketball-reference.com/players/b/bryanth01.html
# Processing 176/193: https://www.basketball-reference.com/players/p/portemi01.html
# Processing 177/193: https://www.basketball-reference.com/players/m/moodymo01.html
# Processing 178/193: https://www.basketball-reference.com/players/h/hausesa01.html
# Processing 179/193: https://www.basketball-reference.com/players/t/thomaca02.html
# Processing 180/193: https://www.basketball-reference.com/players/m/mathube01.html
# Processing 181/193: https://www.basketball-reference.com/players/m/markkla01.html
# Processing 182/193: https://www.basketball-reference.com/players/c/connapa01.html
# Processing 183/193: https://www.basketball-reference.com/players/i/irvinky01.html
# Processing 184/193: https://www.basketball-reference.com/players/b/barrerj01.html
# Processing 185/193: https://www.basketball-reference.com/players/j/jamesle01.html
# Processing 186/193: https://www.basketball-reference.com/players/l/lillada01.html
# Processing 187/193: https://www.basketball-reference.com/players/n/nworajo01.html
# Processing 188/193: https://www.basketball-reference.com/players/w/whiteja03.html
# Processing 189/193: https://www.basketball-reference.com/players/b/bridgmi01.html
# Processing 190/193: https://www.basketball-reference.com/players/d/davisan02.html
# Processing 191/193: https://www.basketball-reference.com/players/w/whiteco01.html
# Processing 192/193: https://www.basketball-reference.com/players/s/smithis01.html
# Processing 193/193: https://www.basketball-reference.com/players/b/bealbr01.html
# Data saved to players_data.csv
# [{'Name': 'Deandre Ayton',
#   'P_ID': 'aytonde01',
#   'Team': 'Portland Trail Blazers',
#   'T_ID': 'POR',
#   'H(cm)': 213,
#   'W(Kg)': 113,
#   'Entry_Age': 21},
#  {'Name': 'Anfernee Simons',
#   'P_ID': 'simonan01',
#   'Team': 'Portland Trail Blazers',
#   'T_ID': 'POR',
#   'H(cm)': 190,
#   'W(Kg)': 82,
#   'Entry_Age': 20},
#  {'Name': 'Svi Mykhailiuk',
#   'P_ID': 'mykhasv01',
#   'Team': 'Utah Jazz',
#   'T_ID': 'UTA',
#   'H(cm)': 201,
#   'W(Kg)': 92,
#   'Entry_Age': 22},
#  {'Name': 'Paul George',
#   'P_ID': 'georgpa01',
#   'Team': 'Philadelphia 76ers',
#   'T_ID': 'PHI',
#   'H(cm)': 203,
#   'W(Kg)': 99,
#   'Entry_Age': 21},
#  {'Name': 'Kelly Oubre Jr.',
#   'P_ID': 'oubreke01',
#   'Team': 'Philadelphia 76ers',
#   'T_ID': 'PHI',
#   'H(cm)': 203,
#   'W(Kg)': 92,
#   'Entry_Age': 21},
#  {'Name': 'Dwight Howard',
#   'P_ID': 'howardw01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 208,
#   'W(Kg)': 120,
#   'Entry_Age': 40},
#  {'Name': 'James Harden',
#   'P_ID': 'hardeja01',
#   'Team': 'Los Angeles Clippers',
#   'T_ID': 'LAC',
#   'H(cm)': 196,
#   'W(Kg)': 99,
#   'Entry_Age': 21},
#  {'Name': 'Hassan Whiteside',
#   'P_ID': 'whiteha01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 213,
#   'W(Kg)': 120,
#   'Entry_Age': 36},
#  {'Name': 'Luke Kornet',
#   'P_ID': 'kornelu01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 218,
#   'W(Kg)': 113,
#   'Entry_Age': 23},
#  {'Name': 'Jimmy Butler',
#   'P_ID': 'butleji01',
#   'Team': 'Miami Heat',
#   'T_ID': 'MIA',
#   'H(cm)': 201,
#   'W(Kg)': 104,
#   'Entry_Age': 23},
#  {'Name': 'Brandon Ingram',
#   'P_ID': 'ingrabr01',
#   'Team': 'New Orleans Pelicans',
#   'T_ID': 'NOP',
#   'H(cm)': 203,
#   'W(Kg)': 86,
#   'Entry_Age': 20},
#  {'Name': 'Torrey Craig',
#   'P_ID': 'craigto01',
#   'Team': 'Chicago Bulls',
#   'T_ID': 'CHI',
#   'H(cm)': 201,
#   'W(Kg)': 100,
#   'Entry_Age': 28},
#  {'Name': 'Kyle Lowry',
#   'P_ID': 'lowryky01',
#   'Team': 'Philadelphia 76ers',
#   'T_ID': 'PHI',
#   'H(cm)': 183,
#   'W(Kg)': 88,
#   'Entry_Age': 21},
#  {'Name': 'Chris Paul',
#   'P_ID': 'paulch01',
#   'Team': 'San Antonio Spurs',
#   'T_ID': 'SAS',
#   'H(cm)': 183,
#   'W(Kg)': 79,
#   'Entry_Age': 21},
#  {'Name': 'Chet Holmgren',
#   'P_ID': 'holmgch01',
#   'Team': 'Oklahoma City Thunder',
#   'T_ID': 'OKC',
#   'H(cm)': 216,
#   'W(Kg)': 96,
#   'Entry_Age': 23},
#  {'Name': 'Juan Toscano-Anderson',
#   'P_ID': 'toscaju01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 198,
#   'W(Kg)': 94,
#   'Entry_Age': 27},
#  {'Name': 'Dalano Banton',
#   'P_ID': 'bantoda01',
#   'Team': 'Portland Trail Blazers',
#   'T_ID': 'POR',
#   'H(cm)': 206,
#   'W(Kg)': 92,
#   'Entry_Age': 23},
#  {'Name': 'Julius Randle',
#   'P_ID': 'randlju01',
#   'Team': 'Minnesota Timberwolves',
#   'T_ID': 'MIN',
#   'H(cm)': 206,
#   'W(Kg)': 113,
#   'Entry_Age': 21},
#  {'Name': 'Justin Jackson',
#   'P_ID': 'jacksju01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 203,
#   'W(Kg)': 99,
#   'Entry_Age': 23},
#  {'Name': 'Brandon Miller',
#   'P_ID': 'millebr02',
#   'Team': 'Charlotte Hornets',
#   'T_ID': 'CHO',
#   'H(cm)': 206,
#   'W(Kg)': 91,
#   'Entry_Age': 23},
#  {'Name': 'Gary Trent Jr.',
#   'P_ID': 'trentga02',
#   'Team': 'Milwaukee Bucks',
#   'T_ID': 'MIL',
#   'H(cm)': 196,
#   'W(Kg)': 94,
#   'Entry_Age': 20},
#  {'Name': 'Danilo Gallinari',
#   'P_ID': 'gallida01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 208,
#   'W(Kg)': 105,
#   'Entry_Age': 23},
#  {'Name': 'Derrick White',
#   'P_ID': 'whitede01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 193,
#   'W(Kg)': 86,
#   'Entry_Age': 24},
#  {'Name': 'Kristaps PorziÅ\x86Ä£is',
#   'P_ID': 'porzikr01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 218,
#   'W(Kg)': 108,
#   'Entry_Age': 22},
#  {'Name': 'Avery Bradley',
#   'P_ID': 'bradlav01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 190,
#   'W(Kg)': 81,
#   'Entry_Age': 35},
#  {'Name': 'Neemias Queta',
#   'P_ID': 'quetane01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 213,
#   'W(Kg)': 111,
#   'Entry_Age': 23},
#  {'Name': 'Davon Reed',
#   'P_ID': 'reedda01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 196,
#   'W(Kg)': 94,
#   'Entry_Age': 26},
#  {'Name': 'Tyrese Maxey',
#   'P_ID': 'maxeyty01',
#   'Team': 'Philadelphia 76ers',
#   'T_ID': 'PHI',
#   'H(cm)': 188,
#   'W(Kg)': 90,
#   'Entry_Age': 21},
#  {'Name': 'Harrison Barnes',
#   'P_ID': 'barneha02',
#   'Team': 'San Antonio Spurs',
#   'T_ID': 'SAS',
#   'H(cm)': 203,
#   'W(Kg)': 102,
#   'Entry_Age': 21},
#  {'Name': 'Jayson Tatum',
#   'P_ID': 'tatumja01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 203,
#   'W(Kg)': 95,
#   'Entry_Age': 20},
#  {'Name': 'Jeff Teague',
#   'P_ID': 'teaguje01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 190,
#   'W(Kg)': 88,
#   'Entry_Age': 37},
#  {'Name': 'Nikola JokiÄ\x87',
#   'P_ID': 'jokicni01',
#   'Team': 'Denver Nuggets',
#   'T_ID': 'DEN',
#   'H(cm)': 211,
#   'W(Kg)': 128,
#   'Entry_Age': 21},
#  {'Name': 'Jamal Murray',
#   'P_ID': 'murraja01',
#   'Team': 'Denver Nuggets',
#   'T_ID': 'DEN',
#   'H(cm)': 193,
#   'W(Kg)': 97,
#   'Entry_Age': 21},
#  {'Name': 'Russell Westbrook',
#   'P_ID': 'westbru01',
#   'Team': 'Denver Nuggets',
#   'T_ID': 'DEN',
#   'H(cm)': 193,
#   'W(Kg)': 90,
#   'Entry_Age': 21},
#  {'Name': 'Donte DiVincenzo',
#   'P_ID': 'divindo01',
#   'Team': 'Minnesota Timberwolves',
#   'T_ID': 'MIN',
#   'H(cm)': 193,
#   'W(Kg)': 92,
#   'Entry_Age': 22},
#  {'Name': 'Joe Harris',
#   'P_ID': 'harrijo01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 198,
#   'W(Kg)': 99,
#   'Entry_Age': 34},
#  {'Name': 'Quinn Cook',
#   'P_ID': 'cookqu01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 185,
#   'W(Kg)': 81,
#   'Entry_Age': 32},
#  {'Name': 'Rodions Kurucs',
#   'P_ID': 'kurucro01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 206,
#   'W(Kg)': 103,
#   'Entry_Age': 27},
#  {'Name': 'Christian Wood',
#   'P_ID': 'woodch01',
#   'Team': 'Los Angeles Lakers',
#   'T_ID': 'LAL',
#   'H(cm)': 203,
#   'W(Kg)': 97,
#   'Entry_Age': 22},
#  {'Name': 'Buddy Hield',
#   'P_ID': 'hieldbu01',
#   'Team': 'Golden State Warriors',
#   'T_ID': 'GSW',
#   'H(cm)': 193,
#   'W(Kg)': 99,
#   'Entry_Age': 25},
#  {'Name': 'Dennis SchrÃ¶der',
#   'P_ID': 'schrode01',
#   'Team': 'Golden State Warriors',
#   'T_ID': 'GSW',
#   'H(cm)': 185,
#   'W(Kg)': 78,
#   'Entry_Age': 21},
#  {'Name': 'JD Davison',
#   'P_ID': 'davisjd01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 185,
#   'W(Kg)': 88,
#   'Entry_Age': 21},
#  {'Name': 'Jaren Jackson Jr.',
#   'P_ID': 'jacksja02',
#   'Team': 'Memphis Grizzlies',
#   'T_ID': 'MEM',
#   'H(cm)': 208,
#   'W(Kg)': 109,
#   'Entry_Age': 20},
#  {'Name': 'Vlatko Ä\x8canÄ\x8dar',
#   'P_ID': 'cancavl01',
#   'Team': 'Denver Nuggets',
#   'T_ID': 'DEN',
#   'H(cm)': 203,
#   'W(Kg)': 107,
#   'Entry_Age': 24},
#  {'Name': 'Nikola VuÄ\x8deviÄ\x87',
#   'P_ID': 'vucevni01',
#   'Team': 'Chicago Bulls',
#   'T_ID': 'CHI',
#   'H(cm)': 208,
#   'W(Kg)': 117,
#   'Entry_Age': 22},
#  {'Name': 'Jalen Green',
#   'P_ID': 'greenja05',
#   'Team': 'Houston Rockets',
#   'T_ID': 'HOU',
#   'H(cm)': 193,
#   'W(Kg)': 80,
#   'Entry_Age': 20},
#  {'Name': 'Terry Rozier',
#   'P_ID': 'roziete01',
#   'Team': 'Miami Heat',
#   'T_ID': 'MIA',
#   'H(cm)': 185,
#   'W(Kg)': 86,
#   'Entry_Age': 22},
#  {'Name': 'Drew Peterson',
#   'P_ID': 'peterdr01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 206,
#   'W(Kg)': 92,
#   'Entry_Age': 26},
#  {'Name': 'Lamar Stevens',
#   'P_ID': 'stevela01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 198,
#   'W(Kg)': 104,
#   'Entry_Age': 24},
#  {'Name': 'Pascal Siakam',
#   'P_ID': 'siakapa01',
#   'Team': 'Indiana Pacers',
#   'T_ID': 'IND',
#   'H(cm)': 203,
#   'W(Kg)': 104,
#   'Entry_Age': 23},
#  {'Name': 'Rudy Gobert',
#   'P_ID': 'goberru01',
#   'Team': 'Minnesota Timberwolves',
#   'T_ID': 'MIN',
#   'H(cm)': 216,
#   'W(Kg)': 117,
#   'Entry_Age': 22},
#  {'Name': 'Jaylen Brown',
#   'P_ID': 'brownja02',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 198,
#   'W(Kg)': 101,
#   'Entry_Age': 21},
#  {'Name': 'Elijah Bryant',
#   'P_ID': 'bryanel01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 196,
#   'W(Kg)': 95,
#   'Entry_Age': 30},
#  {'Name': 'Saddiq Bey',
#   'P_ID': 'beysa01',
#   'Team': 'Washington Wizards',
#   'T_ID': 'WAS',
#   'H(cm)': 201,
#   'W(Kg)': 97,
#   'Entry_Age': 22},
#  {'Name': 'Jarrett Allen',
#   'P_ID': 'allenja01',
#   'Team': 'Cleveland Cavaliers',
#   'T_ID': 'CLE',
#   'H(cm)': 211,
#   'W(Kg)': 110,
#   'Entry_Age': 20},
#  {'Name': 'Khris Middleton',
#   'P_ID': 'middlkh01',
#   'Team': 'Milwaukee Bucks',
#   'T_ID': 'MIL',
#   'H(cm)': 201,
#   'W(Kg)': 100,
#   'Entry_Age': 22},
#  {'Name': 'Evan Mobley',
#   'P_ID': 'mobleev01',
#   'Team': 'Cleveland Cavaliers',
#   'T_ID': 'CLE',
#   'H(cm)': 211,
#   'W(Kg)': 97,
#   'Entry_Age': 21},
#  {'Name': 'Christian Braun',
#   'P_ID': 'braunch01',
#   'Team': 'Denver Nuggets',
#   'T_ID': 'DEN',
#   'H(cm)': 198,
#   'W(Kg)': 98,
#   'Entry_Age': 22},
#  {'Name': 'Joel Embiid',
#   'P_ID': 'embiijo01',
#   'Team': 'Philadelphia 76ers',
#   'T_ID': 'PHI',
#   'H(cm)': 213,
#   'W(Kg)': 127,
#   'Entry_Age': 23},
#  {'Name': 'Alex Caruso',
#   'P_ID': 'carusal01',
#   'Team': 'Oklahoma City Thunder',
#   'T_ID': 'OKC',
#   'H(cm)': 196,
#   'W(Kg)': 84,
#   'Entry_Age': 24},
#  {'Name': 'P.J. Tucker',
#   'P_ID': 'tuckepj01',
#   'Team': 'Los Angeles Clippers',
#   'T_ID': 'LAC',
#   'H(cm)': 196,
#   'W(Kg)': 111,
#   'Entry_Age': 27},
#  {'Name': 'Devin Vassell',
#   'P_ID': 'vassede01',
#   'Team': 'San Antonio Spurs',
#   'T_ID': 'SAS',
#   'H(cm)': 196,
#   'W(Kg)': 90,
#   'Entry_Age': 21},
#  {'Name': 'Victor Wembanyama',
#   'P_ID': 'wembavi01',
#   'Team': 'San Antonio Spurs',
#   'T_ID': 'SAS',
#   'H(cm)': 221,
#   'W(Kg)': 106,
#   'Entry_Age': 21},
#  {'Name': 'Klay Thompson',
#   'P_ID': 'thompkl01',
#   'Team': 'Dallas Mavericks',
#   'T_ID': 'DAL',
#   'H(cm)': 196,
#   'W(Kg)': 97,
#   'Entry_Age': 24},
#  {'Name': 'Miles Bridges',
#   'P_ID': 'bridgmi02',
#   'Team': 'Charlotte Hornets',
#   'T_ID': 'CHO',
#   'H(cm)': 201,
#   'W(Kg)': 102,
#   'Entry_Age': 22},
#  {'Name': 'Quinndary Weatherspoon',
#   'P_ID': 'weathqu01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 190,
#   'W(Kg)': 92,
#   'Entry_Age': 26},
#  {'Name': 'Bam Adebayo',
#   'P_ID': 'adebaba01',
#   'Team': 'Miami Heat',
#   'T_ID': 'MIA',
#   'H(cm)': 206,
#   'W(Kg)': 115,
#   'Entry_Age': 21},
#  {'Name': 'Danny Green',
#   'P_ID': 'greenda02',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 198,
#   'W(Kg)': 97,
#   'Entry_Age': 38},
#  {'Name': 'Nemanja Bjelica',
#   'P_ID': 'bjeline01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 208,
#   'W(Kg)': 106,
#   'Entry_Age': 37},
#  {'Name': 'Norman Powell',
#   'P_ID': 'powelno01',
#   'Team': 'Los Angeles Clippers',
#   'T_ID': 'LAC',
#   'H(cm)': 190,
#   'W(Kg)': 97,
#   'Entry_Age': 23},
#  {'Name': 'Payton Pritchard',
#   'P_ID': 'pritcpa01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 185,
#   'W(Kg)': 88,
#   'Entry_Age': 23},
#  {'Name': 'Andre Iguodala',
#   'P_ID': 'iguodan01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 198,
#   'W(Kg)': 97,
#   'Entry_Age': 41},
#  {'Name': 'Cade Cunningham',
#   'P_ID': 'cunnica01',
#   'Team': 'Detroit Pistons',
#   'T_ID': 'DET',
#   'H(cm)': 198,
#   'W(Kg)': 99,
#   'Entry_Age': 21},
#  {'Name': 'Sam Merrill',
#   'P_ID': 'merrisa01',
#   'Team': 'Cleveland Cavaliers',
#   'T_ID': 'CLE',
#   'H(cm)': 193,
#   'W(Kg)': 92,
#   'Entry_Age': 25},
#  {'Name': 'Montrezl Harrell',
#   'P_ID': 'harremo01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 201,
#   'W(Kg)': 108,
#   'Entry_Age': 23},
#  {'Name': 'Dion Waiters',
#   'P_ID': 'waitedi01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 190,
#   'W(Kg)': 97,
#   'Entry_Age': 34},
#  {'Name': 'Jordan Poole',
#   'P_ID': 'poolejo01',
#   'Team': 'Washington Wizards',
#   'T_ID': 'WAS',
#   'H(cm)': 193,
#   'W(Kg)': 87,
#   'Entry_Age': 21},
#  {'Name': 'Alperen Å\x9eengÃ¼n',
#   'P_ID': 'sengual01',
#   'Team': 'Houston Rockets',
#   'T_ID': 'HOU',
#   'H(cm)': 211,
#   'W(Kg)': 106,
#   'Entry_Age': 20},
#  {'Name': 'Brook Lopez',
#   'P_ID': 'lopezbr01',
#   'Team': 'Milwaukee Bucks',
#   'T_ID': 'MIL',
#   'H(cm)': 216,
#   'W(Kg)': 127,
#   'Entry_Age': 21},
#  {'Name': 'Tim Hardaway Jr.',
#   'P_ID': 'hardati02',
#   'Team': 'Detroit Pistons',
#   'T_ID': 'DET',
#   'H(cm)': 196,
#   'W(Kg)': 92,
#   'Entry_Age': 22},
#  {'Name': 'Luka DonÄ\x8diÄ\x87',
#   'P_ID': 'doncilu01',
#   'Team': 'Dallas Mavericks',
#   'T_ID': 'DAL',
#   'H(cm)': 198,
#   'W(Kg)': 104,
#   'Entry_Age': 20},
#  {'Name': 'Stephen Curry',
#   'P_ID': 'curryst01',
#   'Team': 'Golden State Warriors',
#   'T_ID': 'GSW',
#   'H(cm)': 188,
#   'W(Kg)': 83,
#   'Entry_Age': 22},
#  {'Name': 'Zach LaVine',
#   'P_ID': 'lavinza01',
#   'Team': 'Chicago Bulls',
#   'T_ID': 'CHI',
#   'H(cm)': 196,
#   'W(Kg)': 90,
#   'Entry_Age': 20},
#  {'Name': 'Jaylen Adams',
#   'P_ID': 'adamsja01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 183,
#   'W(Kg)': 102,
#   'Entry_Age': 29},
#  {'Name': 'Zach Norvell',
#   'P_ID': 'norveza01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 196,
#   'W(Kg)': 93,
#   'Entry_Age': 28},
#  {'Name': "Devonte' Graham",
#   'P_ID': 'grahade01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 185,
#   'W(Kg)': 88,
#   'Entry_Age': 24},
#  {'Name': 'Jalen Williams',
#   'P_ID': 'willija06',
#   'Team': 'Oklahoma City Thunder',
#   'T_ID': 'OKC',
#   'H(cm)': 198,
#   'W(Kg)': 99,
#   'Entry_Age': 22},
#  {'Name': 'John Collins',
#   'P_ID': 'collijo01',
#   'Team': 'Utah Jazz',
#   'T_ID': 'UTA',
#   'H(cm)': 206,
#   'W(Kg)': 106,
#   'Entry_Age': 21},
#  {'Name': 'Mamadi Diakite',
#   'P_ID': 'diakima01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 206,
#   'W(Kg)': 103,
#   'Entry_Age': 24},
#  {'Name': 'Peyton Watson',
#   'P_ID': 'watsope01',
#   'Team': 'Denver Nuggets',
#   'T_ID': 'DEN',
#   'H(cm)': 203,
#   'W(Kg)': 90,
#   'Entry_Age': 21},
#  {'Name': 'J.R. Smith',
#   'P_ID': 'smithjr01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 198,
#   'W(Kg)': 102,
#   'Entry_Age': 40},
#  {'Name': 'Giannis Antetokounmpo',
#   'P_ID': 'antetgi01',
#   'Team': 'Milwaukee Bucks',
#   'T_ID': 'MIL',
#   'H(cm)': 211,
#   'W(Kg)': 109,
#   'Entry_Age': 20},
#  {'Name': 'Dejounte Murray',
#   'P_ID': 'murrade01',
#   'Team': 'New Orleans Pelicans',
#   'T_ID': 'NOP',
#   'H(cm)': 196,
#   'W(Kg)': 81,
#   'Entry_Age': 22},
#  {'Name': 'Darius Garland',
#   'P_ID': 'garlada01',
#   'Team': 'Cleveland Cavaliers',
#   'T_ID': 'CLE',
#   'H(cm)': 185,
#   'W(Kg)': 87,
#   'Entry_Age': 20},
#  {'Name': 'Troy Daniels',
#   'P_ID': 'danietr01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 193,
#   'W(Kg)': 90,
#   'Entry_Age': 34},
#  {'Name': 'Desmond Bane',
#   'P_ID': 'banede01',
#   'Team': 'Memphis Grizzlies',
#   'T_ID': 'MEM',
#   'H(cm)': 196,
#   'W(Kg)': 97,
#   'Entry_Age': 23},
#  {'Name': 'Zeke Nnaji',
#   'P_ID': 'nnajize01',
#   'Team': 'Denver Nuggets',
#   'T_ID': 'DEN',
#   'H(cm)': 206,
#   'W(Kg)': 108,
#   'Entry_Age': 20},
#  {'Name': 'Rajon Rondo',
#   'P_ID': 'rondora01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 185,
#   'W(Kg)': 81,
#   'Entry_Age': 39},
#  {'Name': "D'Angelo Russell",
#   'P_ID': 'russeda01',
#   'Team': 'Brooklyn Nets',
#   'T_ID': 'BRK',
#   'H(cm)': 190,
#   'W(Kg)': 87,
#   'Entry_Age': 20},
#  {'Name': 'Jordan Clarkson',
#   'P_ID': 'clarkjo01',
#   'Team': 'Utah Jazz',
#   'T_ID': 'UTA',
#   'H(cm)': 190,
#   'W(Kg)': 87,
#   'Entry_Age': 23},
#  {'Name': 'Kevin Durant',
#   'P_ID': 'duranke01',
#   'Team': 'Phoenix Suns',
#   'T_ID': 'PHO',
#   'H(cm)': 211,
#   'W(Kg)': 108,
#   'Entry_Age': 21},
#  {'Name': 'Trae Young',
#   'P_ID': 'youngtr01',
#   'Team': 'Atlanta Hawks',
#   'T_ID': 'ATL',
#   'H(cm)': 185,
#   'W(Kg)': 74,
#   'Entry_Age': 21},
#  {'Name': 'Kawhi Leonard',
#   'P_ID': 'leonaka01',
#   'Team': 'Los Angeles Clippers',
#   'T_ID': 'LAC',
#   'H(cm)': 201,
#   'W(Kg)': 102,
#   'Entry_Age': 22},
#  {'Name': 'Kemba Walker',
#   'P_ID': 'walkeke02',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 183,
#   'W(Kg)': 83,
#   'Entry_Age': 35},
#  {'Name': 'Bobby Portis',
#   'P_ID': 'portibo01',
#   'Team': 'Milwaukee Bucks',
#   'T_ID': 'MIL',
#   'H(cm)': 208,
#   'W(Kg)': 113,
#   'Entry_Age': 21},
#  {'Name': 'Kevon Looney',
#   'P_ID': 'looneke01',
#   'Team': 'Golden State Warriors',
#   'T_ID': 'GSW',
#   'H(cm)': 206,
#   'W(Kg)': 100,
#   'Entry_Age': 20},
#  {'Name': 'Jonathan Kuminga',
#   'P_ID': 'kuminjo01',
#   'Team': 'Golden State Warriors',
#   'T_ID': 'GSW',
#   'H(cm)': 203,
#   'W(Kg)': 95,
#   'Entry_Age': 20},
#  {'Name': 'Tyler Herro',
#   'P_ID': 'herroty01',
#   'Team': 'Miami Heat',
#   'T_ID': 'MIA',
#   'H(cm)': 196,
#   'W(Kg)': 88,
#   'Entry_Age': 20},
#  {'Name': 'Jordan Walsh',
#   'P_ID': 'walshjo01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 201,
#   'W(Kg)': 92,
#   'Entry_Age': 21},
#  {'Name': 'Bruce Brown',
#   'P_ID': 'brownbr01',
#   'Team': 'Toronto Raptors',
#   'T_ID': 'TOR',
#   'H(cm)': 193,
#   'W(Kg)': 91,
#   'Entry_Age': 23},
#  {'Name': 'DeAndre Jordan',
#   'P_ID': 'jordade01',
#   'Team': 'Denver Nuggets',
#   'T_ID': 'DEN',
#   'H(cm)': 211,
#   'W(Kg)': 120,
#   'Entry_Age': 21},
#  {'Name': 'Ja Morant',
#   'P_ID': 'moranja01',
#   'Team': 'Memphis Grizzlies',
#   'T_ID': 'MEM',
#   'H(cm)': 188,
#   'W(Kg)': 78,
#   'Entry_Age': 21},
#  {'Name': 'Xavier Tillman Sr.',
#   'P_ID': 'tillmxa01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 203,
#   'W(Kg)': 111,
#   'Entry_Age': 22},
#  {'Name': 'Collin Sexton',
#   'P_ID': 'sextoco01',
#   'Team': 'Utah Jazz',
#   'T_ID': 'UTA',
#   'H(cm)': 190,
#   'W(Kg)': 86,
#   'Entry_Age': 20},
#  {'Name': 'Chris Chiozza',
#   'P_ID': 'chiozch01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 180,
#   'W(Kg)': 79,
#   'Entry_Age': 26},
#  {'Name': 'Karl-Anthony Towns',
#   'P_ID': 'townska01',
#   'Team': 'New York Knicks',
#   'T_ID': 'NYK',
#   'H(cm)': 213,
#   'W(Kg)': 112,
#   'Entry_Age': 21},
#  {'Name': 'Tyrese Haliburton',
#   'P_ID': 'halibty01',
#   'Team': 'Indiana Pacers',
#   'T_ID': 'IND',
#   'H(cm)': 196,
#   'W(Kg)': 83,
#   'Entry_Age': 21},
#  {'Name': 'Malcolm Brogdon',
#   'P_ID': 'brogdma01',
#   'Team': 'Washington Wizards',
#   'T_ID': 'WAS',
#   'H(cm)': 193,
#   'W(Kg)': 103,
#   'Entry_Age': 25},
#  {'Name': 'Dillon Brooks',
#   'P_ID': 'brookdi01',
#   'Team': 'Houston Rockets',
#   'T_ID': 'HOU',
#   'H(cm)': 198,
#   'W(Kg)': 102,
#   'Entry_Age': 22},
#  {'Name': 'Bones Hyland',
#   'P_ID': 'hylanbo01',
#   'Team': 'Los Angeles Clippers',
#   'T_ID': 'LAC',
#   'H(cm)': 188,
#   'W(Kg)': 78,
#   'Entry_Age': 22},
#  {'Name': 'Kentavious Caldwell-Pope',
#   'P_ID': 'caldwke01',
#   'Team': 'Orlando Magic',
#   'T_ID': 'ORL',
#   'H(cm)': 196,
#   'W(Kg)': 92,
#   'Entry_Age': 21},
#  {'Name': 'Jared Dudley',
#   'P_ID': 'dudleja01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 198,
#   'W(Kg)': 107,
#   'Entry_Age': 40},
#  {'Name': 'Shai Gilgeous-Alexander',
#   'P_ID': 'gilgesh01',
#   'Team': 'Oklahoma City Thunder',
#   'T_ID': 'OKC',
#   'H(cm)': 198,
#   'W(Kg)': 90,
#   'Entry_Age': 21},
#  {'Name': 'Bojan BogdanoviÄ\x87',
#   'P_ID': 'bogdabo02',
#   'Team': 'Brooklyn Nets',
#   'T_ID': 'BRK',
#   'H(cm)': 201,
#   'W(Kg)': 102,
#   'Entry_Age': 26},
#  {'Name': 'CJ McCollum',
#   'P_ID': 'mccolcj01',
#   'Team': 'New Orleans Pelicans',
#   'T_ID': 'NOP',
#   'H(cm)': 190,
#   'W(Kg)': 86,
#   'Entry_Age': 23},
#  {'Name': 'Otto Porter Jr.',
#   'P_ID': 'porteot01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 203,
#   'W(Kg)': 89,
#   'Entry_Age': 32},
#  {'Name': "De'Aaron Fox",
#   'P_ID': 'foxde01',
#   'Team': 'Sacramento Kings',
#   'T_ID': 'SAC',
#   'H(cm)': 190,
#   'W(Kg)': 83,
#   'Entry_Age': 21},
#  {'Name': 'T.J. Warren',
#   'P_ID': 'warretj01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 203,
#   'W(Kg)': 99,
#   'Entry_Age': 23},
#  {'Name': 'JaVale McGee',
#   'P_ID': 'mcgeeja01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 213,
#   'W(Kg)': 122,
#   'Entry_Age': 21},
#  {'Name': 'Kyle Kuzma',
#   'P_ID': 'kuzmaky01',
#   'Team': 'Washington Wizards',
#   'T_ID': 'WAS',
#   'H(cm)': 206,
#   'W(Kg)': 100,
#   'Entry_Age': 23},
#  {'Name': 'Jonas ValanÄ\x8diÅ«nas',
#   'P_ID': 'valanjo01',
#   'Team': 'Washington Wizards',
#   'T_ID': 'WAS',
#   'H(cm)': 211,
#   'W(Kg)': 120,
#   'Entry_Age': 21},
#  {'Name': 'Donovan Mitchell',
#   'P_ID': 'mitchdo01',
#   'Team': 'Cleveland Cavaliers',
#   'T_ID': 'CLE',
#   'H(cm)': 190,
#   'W(Kg)': 97,
#   'Entry_Age': 22},
#  {'Name': 'Kostas Antetokounmpo',
#   'P_ID': 'antetko01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 208,
#   'W(Kg)': 90,
#   'Entry_Age': 25},
#  {'Name': 'Jaden Springer',
#   'P_ID': 'sprinja01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 193,
#   'W(Kg)': 92,
#   'Entry_Age': 20},
#  {'Name': 'Fred VanVleet',
#   'P_ID': 'vanvlfr01',
#   'Team': 'Houston Rockets',
#   'T_ID': 'HOU',
#   'H(cm)': 183,
#   'W(Kg)': 89,
#   'Entry_Age': 23},
#  {'Name': 'Talen Horton-Tucker',
#   'P_ID': 'hortota01',
#   'Team': 'Chicago Bulls',
#   'T_ID': 'CHI',
#   'H(cm)': 193,
#   'W(Kg)': 106,
#   'Entry_Age': 20},
#  {'Name': 'Spencer Dinwiddie',
#   'P_ID': 'dinwisp01',
#   'Team': 'Dallas Mavericks',
#   'T_ID': 'DAL',
#   'H(cm)': 196,
#   'W(Kg)': 97,
#   'Entry_Age': 22},
#  {'Name': 'Zion Williamson',
#   'P_ID': 'willizi01',
#   'Team': 'New Orleans Pelicans',
#   'T_ID': 'NOP',
#   'H(cm)': 198,
#   'W(Kg)': 128,
#   'Entry_Age': 21},
#  {'Name': 'Markieff Morris',
#   'P_ID': 'morrima02',
#   'Team': 'Dallas Mavericks',
#   'T_ID': 'DAL',
#   'H(cm)': 206,
#   'W(Kg)': 111,
#   'Entry_Age': 23},
#  {'Name': 'Jalen Brunson',
#   'P_ID': 'brunsja01',
#   'Team': 'New York Knicks',
#   'T_ID': 'NYK',
#   'H(cm)': 188,
#   'W(Kg)': 86,
#   'Entry_Age': 23},
#  {'Name': 'Al Horford',
#   'P_ID': 'horfoal01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 206,
#   'W(Kg)': 108,
#   'Entry_Age': 22},
#  {'Name': 'Anthony Edwards',
#   'P_ID': 'edwaran01',
#   'Team': 'Minnesota Timberwolves',
#   'T_ID': 'MIN',
#   'H(cm)': 193,
#   'W(Kg)': 102,
#   'Entry_Age': 20},
#  {'Name': 'Andrew Wiggins',
#   'P_ID': 'wiggian01',
#   'Team': 'Golden State Warriors',
#   'T_ID': 'GSW',
#   'H(cm)': 201,
#   'W(Kg)': 89,
#   'Entry_Age': 20},
#  {'Name': 'Tobias Harris',
#   'P_ID': 'harrito02',
#   'Team': 'Detroit Pistons',
#   'T_ID': 'DET',
#   'H(cm)': 203,
#   'W(Kg)': 102,
#   'Entry_Age': 20},
#  {'Name': 'Thanasis Antetokounmpo',
#   'P_ID': 'antetth01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 201,
#   'W(Kg)': 99,
#   'Entry_Age': 27},
#  {'Name': 'Myles Turner',
#   'P_ID': 'turnemy01',
#   'Team': 'Indiana Pacers',
#   'T_ID': 'IND',
#   'H(cm)': 211,
#   'W(Kg)': 113,
#   'Entry_Age': 20},
#  {'Name': 'Domantas Sabonis',
#   'P_ID': 'sabondo01',
#   'Team': 'Sacramento Kings',
#   'T_ID': 'SAC',
#   'H(cm)': 208,
#   'W(Kg)': 108,
#   'Entry_Age': 21},
#  {'Name': 'Oshae Brissett',
#   'P_ID': 'brissos01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 201,
#   'W(Kg)': 95,
#   'Entry_Age': 22},
#  {'Name': 'LaMelo Ball',
#   'P_ID': 'ballla01',
#   'Team': 'Charlotte Hornets',
#   'T_ID': 'CHO',
#   'H(cm)': 201,
#   'W(Kg)': 81,
#   'Entry_Age': 20},
#  {'Name': 'Bryn Forbes',
#   'P_ID': 'forbebr01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 188,
#   'W(Kg)': 92,
#   'Entry_Age': 25},
#  {'Name': 'Jeff Green',
#   'P_ID': 'greenje02',
#   'Team': 'Houston Rockets',
#   'T_ID': 'HOU',
#   'H(cm)': 203,
#   'W(Kg)': 106,
#   'Entry_Age': 23},
#  {'Name': 'Axel Toupane',
#   'P_ID': 'toupaax01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 201,
#   'W(Kg)': 89,
#   'Entry_Age': 33},
#  {'Name': 'D.J. Augustin',
#   'P_ID': 'augusdj01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 180,
#   'W(Kg)': 83,
#   'Entry_Age': 38},
#  {'Name': 'Franz Wagner',
#   'P_ID': 'wagnefr01',
#   'Team': 'Orlando Magic',
#   'T_ID': 'ORL',
#   'H(cm)': 208,
#   'W(Kg)': 102,
#   'Entry_Age': 21},
#  {'Name': 'DeMar DeRozan',
#   'P_ID': 'derozde01',
#   'Team': 'Sacramento Kings',
#   'T_ID': 'SAC',
#   'H(cm)': 198,
#   'W(Kg)': 99,
#   'Entry_Age': 21},
#  {'Name': 'Jerami Grant',
#   'P_ID': 'grantje01',
#   'Team': 'Portland Trail Blazers',
#   'T_ID': 'POR',
#   'H(cm)': 201,
#   'W(Kg)': 95,
#   'Entry_Age': 21},
#  {'Name': 'Draymond Green',
#   'P_ID': 'greendr01',
#   'Team': 'Golden State Warriors',
#   'T_ID': 'GSW',
#   'H(cm)': 198,
#   'W(Kg)': 104,
#   'Entry_Age': 23},
#  {'Name': 'Devontae Cacok',
#   'P_ID': 'cacokde01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 201,
#   'W(Kg)': 108,
#   'Entry_Age': 26},
#  {'Name': 'Keldon Johnson',
#   'P_ID': 'johnske04',
#   'Team': 'San Antonio Spurs',
#   'T_ID': 'SAS',
#   'H(cm)': 196,
#   'W(Kg)': 99,
#   'Entry_Age': 21},
#  {'Name': 'Evan Fournier',
#   'P_ID': 'fournev01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 198,
#   'W(Kg)': 92,
#   'Entry_Age': 21},
#  {'Name': 'Jrue Holiday',
#   'P_ID': 'holidjr01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 193,
#   'W(Kg)': 92,
#   'Entry_Age': 20},
#  {'Name': 'Lou Williams',
#   'P_ID': 'willilo02',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 188,
#   'W(Kg)': 79,
#   'Entry_Age': 39},
#  {'Name': 'Damion Lee',
#   'P_ID': 'leeda03',
#   'Team': 'Phoenix Suns',
#   'T_ID': 'PHO',
#   'H(cm)': 196,
#   'W(Kg)': 95,
#   'Entry_Age': 27},
#  {'Name': 'Reggie Jackson',
#   'P_ID': 'jacksre01',
#   'Team': 'Philadelphia 76ers',
#   'T_ID': 'PHI',
#   'H(cm)': 188,
#   'W(Kg)': 94,
#   'Entry_Age': 22},
#  {'Name': 'Jeff Dowtin',
#   'P_ID': 'dowtije01',
#   'Team': 'Philadelphia 76ers',
#   'T_ID': 'PHI',
#   'H(cm)': 190,
#   'W(Kg)': 83,
#   'Entry_Age': 25},
#  {'Name': 'D.J. Wilson',
#   'P_ID': 'wilsodj01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 208,
#   'W(Kg)': 104,
#   'Entry_Age': 23},
#  {'Name': 'Austin Reaves',
#   'P_ID': 'reaveau01',
#   'Team': 'Los Angeles Lakers',
#   'T_ID': 'LAL',
#   'H(cm)': 196,
#   'W(Kg)': 93,
#   'Entry_Age': 24},
#  {'Name': 'Gary Payton II',
#   'P_ID': 'paytoga02',
#   'Team': 'Golden State Warriors',
#   'T_ID': 'GSW',
#   'H(cm)': 188,
#   'W(Kg)': 86,
#   'Entry_Age': 25},
#  {'Name': 'Aaron Gordon',
#   'P_ID': 'gordoaa01',
#   'Team': 'Denver Nuggets',
#   'T_ID': 'DEN',
#   'H(cm)': 203,
#   'W(Kg)': 106,
#   'Entry_Age': 20},
#  {'Name': 'Devin Booker',
#   'P_ID': 'bookede01',
#   'Team': 'Phoenix Suns',
#   'T_ID': 'PHO',
#   'H(cm)': 198,
#   'W(Kg)': 93,
#   'Entry_Age': 20},
#  {'Name': 'Paolo Banchero',
#   'P_ID': 'banchpa01',
#   'Team': 'Orlando Magic',
#   'T_ID': 'ORL',
#   'H(cm)': 208,
#   'W(Kg)': 113,
#   'Entry_Age': 21},
#  {'Name': 'Josh Giddey',
#   'P_ID': 'giddejo01',
#   'Team': 'Chicago Bulls',
#   'T_ID': 'CHI',
#   'H(cm)': 203,
#   'W(Kg)': 95,
#   'Entry_Age': 20},
#  {'Name': 'Marcus Morris',
#   'P_ID': 'morrima03',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 203,
#   'W(Kg)': 98,
#   'Entry_Age': 23},
#  {'Name': 'Bogdan BogdanoviÄ\x87',
#   'P_ID': 'bogdabo01',
#   'Team': 'Atlanta Hawks',
#   'T_ID': 'ATL',
#   'H(cm)': 196,
#   'W(Kg)': 99,
#   'Entry_Age': 26},
#  {'Name': 'Thomas Bryant',
#   'P_ID': 'bryanth01',
#   'Team': 'Indiana Pacers',
#   'T_ID': 'IND',
#   'H(cm)': 208,
#   'W(Kg)': 112,
#   'Entry_Age': 21},
#  {'Name': 'Michael Porter Jr.',
#   'P_ID': 'portemi01',
#   'Team': 'Denver Nuggets',
#   'T_ID': 'DEN',
#   'H(cm)': 208,
#   'W(Kg)': 98,
#   'Entry_Age': 22},
#  {'Name': 'Moses Moody',
#   'P_ID': 'moodymo01',
#   'Team': 'Golden State Warriors',
#   'T_ID': 'GSW',
#   'H(cm)': 196,
#   'W(Kg)': 92,
#   'Entry_Age': 20},
#  {'Name': 'Sam Hauser',
#   'P_ID': 'hausesa01',
#   'Team': 'Boston Celtics',
#   'T_ID': 'BOS',
#   'H(cm)': 203,
#   'W(Kg)': 97,
#   'Entry_Age': 25},
#  {'Name': 'Cam Thomas',
#   'P_ID': 'thomaca02',
#   'Team': 'Brooklyn Nets',
#   'T_ID': 'BRK',
#   'H(cm)': 193,
#   'W(Kg)': 95,
#   'Entry_Age': 21},
#  {'Name': 'Bennedict Mathurin',
#   'P_ID': 'mathube01',
#   'Team': 'Indiana Pacers',
#   'T_ID': 'IND',
#   'H(cm)': 198,
#   'W(Kg)': 95,
#   'Entry_Age': 21},
#  {'Name': 'Lauri Markkanen',
#   'P_ID': 'markkla01',
#   'Team': 'Utah Jazz',
#   'T_ID': 'UTA',
#   'H(cm)': 213,
#   'W(Kg)': 108,
#   'Entry_Age': 21},
#  {'Name': 'Pat Connaughton',
#   'P_ID': 'connapa01',
#   'Team': 'Milwaukee Bucks',
#   'T_ID': 'MIL',
#   'H(cm)': 196,
#   'W(Kg)': 94,
#   'Entry_Age': 23},
#  {'Name': 'Kyrie Irving',
#   'P_ID': 'irvinky01',
#   'Team': 'Dallas Mavericks',
#   'T_ID': 'DAL',
#   'H(cm)': 188,
#   'W(Kg)': 88,
#   'Entry_Age': 20},
#  {'Name': 'RJ Barrett',
#   'P_ID': 'barrerj01',
#   'Team': 'Toronto Raptors',
#   'T_ID': 'TOR',
#   'H(cm)': 198,
#   'W(Kg)': 97,
#   'Entry_Age': 20},
#  {'Name': 'LeBron James',
#   'P_ID': 'jamesle01',
#   'Team': 'Los Angeles Lakers',
#   'T_ID': 'LAL',
#   'H(cm)': 206,
#   'W(Kg)': 113,
#   'Entry_Age': 20},
#  {'Name': 'Damian Lillard',
#   'P_ID': 'lillada01',
#   'Team': 'Milwaukee Bucks',
#   'T_ID': 'MIL',
#   'H(cm)': 188,
#   'W(Kg)': 88,
#   'Entry_Age': 23},
#  {'Name': 'Jordan Nwora',
#   'P_ID': 'nworajo01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 203,
#   'W(Kg)': 102,
#   'Entry_Age': 23},
#  {'Name': 'Jack White',
#   'P_ID': 'whiteja03',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 201,
#   'W(Kg)': 102,
#   'Entry_Age': 26},
#  {'Name': 'Mikal Bridges',
#   'P_ID': 'bridgmi01',
#   'Team': 'New York Knicks',
#   'T_ID': 'NYK',
#   'H(cm)': 198,
#   'W(Kg)': 94,
#   'Entry_Age': 23},
#  {'Name': 'Anthony Davis',
#   'P_ID': 'davisan02',
#   'Team': 'Los Angeles Lakers',
#   'T_ID': 'LAL',
#   'H(cm)': 208,
#   'W(Kg)': 114,
#   'Entry_Age': 20},
#  {'Name': 'Coby White',
#   'P_ID': 'whiteco01',
#   'Team': 'Chicago Bulls',
#   'T_ID': 'CHI',
#   'H(cm)': 196,
#   'W(Kg)': 88,
#   'Entry_Age': 20},
#  {'Name': 'Ish Smith',
#   'P_ID': 'smithis01',
#   'Team': 'Not Listed',
#   'T_ID': 'Not Listed',
#   'H(cm)': 183,
#   'W(Kg)': 79,
#   'Entry_Age': 23},
#  {'Name': 'Bradley Beal',
#   'P_ID': 'bealbr01',
#   'Team': 'Phoenix Suns',
#   'T_ID': 'PHO',
#   'H(cm)': 193,
#   'W(Kg)': 93,
#   'Entry_Age': 20}]

# %%
## hala ma kole team hayi ke bahashoon kar darim, team haye hamin 193 ta bazikone

# %%
def extract_unique_team_ids(players_data):
    t_ids = list(set([player['T_ID'] for player in players_data if player['T_ID'] != "Not Listed"]))
    return t_ids

# Load data from CSV and extract unique T_IDs
def load_and_extract_t_ids(file_name):
    with open(file_name, mode='r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        t_ids = list(set(row['T_ID'] for row in reader if row['T_ID'] != "Not Listed"))
    return t_ids
file_name = "players_data.csv"
unique_team_ids = load_and_extract_t_ids(file_name)
print(unique_team_ids)
print(len(unique_team_ids))
# Out:
# ['TOR', 'PHI', 'WAS', 'MIL', 'NYK', 'CHO', 'HOU', 'BOS', 'BRK', 'IND', 'SAC', 'LAC', 'MIA', 'MIN', 'DAL', 'CLE', 'DET', 'SAS', 'DEN', 'CHI', 'NOP', 'ORL', 'GSW', 'MEM', 'ATL', 'OKC', 'LAL', 'UTA', 'PHO', 'POR']
# 30

# %%
## alan faghat kafie in ID haye bala ro be code zir bedim!

# %%
class BasketballTeamScraper:
    def __init__(self, T_ID):
        self.T_ID = T_ID
        self.base_url = f"https://www.basketball-reference.com/teams/{self.T_ID}/"
        self.soup = None
        self.team_info = None

    def fetch_data(self):
        """Fetch the webpage content and parse it with BeautifulSoup."""
        response = requests.get(self.base_url)
        if response.status_code == 200:
            self.soup = BeautifulSoup(response.text, 'html.parser')
        else:
            raise Exception(f"Failed to fetch the webpage. Status code: {response.status_code}")

    def extract_team_info(self):
        """Extract information about the team."""
        if not self.soup:
            raise Exception("No HTML content found. Call fetch_data() first.")

        # Extract Location
        location_tag = self.soup.find("strong", string="Location:")
        location = location_tag.next_sibling.strip() if location_tag else "N/A"

        # Extract Team Name
        team_name_tag = self.soup.find("h1").find("span")
        team_name = team_name_tag.text.strip() if team_name_tag else "N/A"

        # Extract Active Seasons and Established Year
        seasons_tag = self.soup.find("strong", string="Seasons:")
        if seasons_tag:
            seasons_text = seasons_tag.parent.get_text(strip=True).replace("Seasons:", "").strip()
            active_seasons = seasons_text.split(";")[0].strip()
            established_year = seasons_text.split(";")[1].strip().split("-")[0]
        else:
            active_seasons = "N/A"
            established_year = "N/A"

        # Extract Playoff Appearances
        playoff_appearances_tag = self.soup.find("strong", string="Playoff Appearances:")
        playoff_appearances = playoff_appearances_tag.next_sibling.strip() if playoff_appearances_tag else "N/A"

        # Extract Championships
        championships_tag = self.soup.find("strong", string="Championships:")
        championships = championships_tag.next_sibling.strip() if championships_tag else "N/A"

        # Store the data as a dictionary
        self.team_info = {
            "Team ID": self.T_ID,
            "Location": location,
            "Team Name": team_name,
            "Active Seasons": active_seasons,
            "Established Year": established_year,
            "Playoff Appearances": playoff_appearances,
            "Championships": championships
        }

    def save_to_csv(self, filename):
        """Save the extracted team info to a CSV file."""
        if not self.team_info:
            raise Exception("No data to save. Call extract_team_info() first.")

        # Convert the dictionary to a DataFrame
        df = pd.DataFrame([self.team_info])
        df.to_csv(filename, index=False)

        return df

# Example Usage
if __name__ == "__main__":
    T_ID = "LAL"  # Example Team ID for Los Angeles Lakers
    scraper = BasketballTeamScraper(T_ID)

    try:
        scraper.fetch_data()
        scraper.extract_team_info()

        # Save to CSV and display as a table
        output_filename = f"{T_ID}_team_info.csv"
        team_info_df = scraper.save_to_csv(output_filename)

        print("Team Information Table:")
        print(team_info_df)

    except Exception as e:
        print("Error:", e)
# Out:
# Team Information Table:
#   Team ID                 Location           Team Name Active Seasons  \
# 0     LAL  Los Angeles, California  Los Angeles Lakers             77
#
#   Established Year Playoff Appearances Championships
# 0             1948                  64            17

# %%
# Initialize an empty list to store all team data
all_team_data = []

# Iterate through each team ID and scrape its data
for T_ID in unique_team_ids:
    scraper = BasketballTeamScraper(T_ID)
    try:
        scraper.fetch_data()
        scraper.extract_team_info()
        all_team_data.append(scraper.team_info)
        print(f"Successfully scraped data for team: {T_ID}")
        
        # Add a delay to slow down the scraping process
        time.sleep(2)  # Wait 5 seconds between each request
    except Exception as e:
        print(f"Error scraping data for team {T_ID}: {e}")

# Save all team data to a CSV file
output_filename = "all_teams_data.csv"
df = pd.DataFrame(all_team_data)
df.to_csv(output_filename, index=False)

print(f"All team data saved to {output_filename}")
# Out:
# Successfully scraped data for team: TOR
# Successfully scraped data for team: PHI
# Successfully scraped data for team: WAS
# Successfully scraped data for team: MIL
# Successfully scraped data for team: NYK
# Error scraping data for team CHO: 'NoneType' object has no attribute 'find'
# Successfully scraped data for team: HOU
# Successfully scraped data for team: BOS
# Error scraping data for team BRK: 'NoneType' object has no attribute 'find'
# Successfully scraped data for team: IND
# Successfully scraped data for team: SAC
# Successfully scraped data for team: LAC
# Successfully scraped data for team: MIA
# Successfully scraped data for team: MIN
# Successfully scraped data for team: DAL
# Successfully scraped data for team: CLE
# Successfully scraped data for team: DET
# Successfully scraped data for team: SAS
# Successfully scraped data for team: DEN
# Successfully scraped data for team: CHI
# Error scraping data for team NOP: 'NoneType' object has no attribute 'find'
# Successfully scraped data for team: ORL
# Successfully scraped data for team: GSW
# Successfully scraped data for team: MEM
# Successfully scraped data for team: ATL
# Successfully scraped data for team: OKC
# Successfully scraped data for team: LAL
# Successfully scraped data for team: UTA
# Successfully scraped data for team: PHO
# Successfully scraped data for team: POR
# All team data saved to all_teams_data.csv

# %%
## Link of MVP Players

# %%
# Finding the NBA MVP page
mvp_page_url = None
for i in s:
    if i.text == 'NBA MVP':
        mvp_page_url = 'https://www.basketball-reference.com' + i['href']
        break

# Fetch the MVP voting page
if mvp_page_url:
    page = requests.get(mvp_page_url, headers=headers)
    soup = BeautifulSoup(page.content, 'html.parser')

    # Extract the first 5 MVP voting links
    mvp_links = [
        'https://www.basketball-reference.com' + i['href']
        for i in soup.find_all('a') if i.text == 'V'
    ][:5]  # Keep only the first 5 links

# Extract MVP player profile links per year
mvp_player_links = {}

for i, link in enumerate(mvp_links):
    page = requests.get(link, headers=headers)
    soup = BeautifulSoup(page.content, 'html.parser')

    # Find player links from the first table
    tables = soup.find_all('tbody')
    if tables:
        mvp_player_links[2024 - i] = [
            'https://www.basketball-reference.com' + a['href']
            for a in tables[0].find_all('a') if 'players' in a['href']
        ]

# Assigning MVP player links for each year
mvp2024_link = mvp_player_links.get(2024, [])
mvp2023_link = mvp_player_links.get(2023, [])
mvp2022_link = mvp_player_links.get(2022, [])
mvp2021_link = mvp_player_links.get(2021, [])
mvp2020_link = mvp_player_links.get(2020, [])

# Print the number of MVP player links found per year
for year in range(2024, 2019, -1):
    print(f"{year}: {len(mvp_player_links.get(year, []))} players")
# Out:
# 2024: 9 players
# 2023: 13 players
# 2022: 12 players
# 2021: 15 players
# 2020: 12 players

# %% [markdown]
# ## Jordan Scrapper

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def scrape_mvp_tables(urls):
    all_data = []

    for url in urls:
        try:
            # Send a request to the webpage with timeout
            response = requests.get(url, timeout=10)
            response.raise_for_status()  # Raise HTTPError for bad responses
            soup = BeautifulSoup(response.content, 'html.parser')

            # Find the MVP table
            mvp_table = soup.find('table', {'id': 'mvp'})

            if not mvp_table:
                print(f"MVP table not found on {url}")
                continue

            # Extract all rows from the table
            rows = mvp_table.find_all('tr')

            # Extract data from each row
            for row in rows:
                cols = row.find_all(['th', 'td'])  # Include header cells for correct indexing
                if len(cols) >= 8:  # Ensure enough columns are present
                    rank = cols[0].text.strip()
                    player = cols[1].text.strip()
                    team = cols[3].text.strip()
                    points_won = cols[5].text.strip()
                    points_max = cols[6].text.strip()
                    share = cols[7].text.strip()
                    all_data.append({
                        'Rank': rank,
                        'Player': player,
                        'Tm': team,
                        'Pts Won': points_won,
                        'Pts Max': points_max,
                        'Share': share,
                        'Source URL': url
                    })

            # Add a delay between requests
            time.sleep(2)

        except requests.exceptions.RequestException as e:
            print(f"Error fetching data from {url}: {e}")

    # Convert to DataFrame
    df = pd.DataFrame(all_data)

    # Save to CSV
    df.to_csv('mvp_data_combined.csv', index=False)

    # Print the extracted data
    print(df)

# Example usage
urls = list(mvp_links)  # Use dynamically extracted MVP voting page URLs
scrape_mvp_tables(urls)
# Out:
#     Rank                   Player   Tm  Pts Won  Pts Max  Share  \
# 0   Rank                   Player   Tm  Pts Won  Pts Max  Share
# 1      1             Nikola Jokić  DEN      926      990  0.935
# 2      2  Shai Gilgeous-Alexander  OKC      640      990  0.646
# 3      3              Luka Dončić  DAL      566      990  0.572
# 4      4    Giannis Antetokounmpo  MIL      192      990  0.194
# ..   ...                      ...  ...      ...      ...    ...
# 61     8           Damian Lillard  POR       23     1010  0.023
# 62     9             Nikola Jokić  DEN       18     1010  0.018
# 63    10            Pascal Siakam  TOR       17     1010  0.017
# 64    11             Jimmy Butler  MIA        9     1010  0.009
# 65    12             Jayson Tatum  BOS        1     1010  0.001
#
#                                            Source URL
# 0   https://www.basketball-reference.com/awards/aw...
# 1   https://www.basketball-reference.com/awards/aw...
# 2   https://www.basketball-reference.com/awards/aw...
# 3   https://www.basketball-reference.com/awards/aw...
# 4   https://www.basketball-reference.com/awards/aw...
# ..                                                ...
# 61  https://www.basketball-reference.com/awards/aw...
# 62  https://www.basketball-reference.com/awards/aw...
# 63  https://www.basketball-reference.com/awards/aw...
# 64  https://www.basketball-reference.com/awards/aw...
# 65  https://www.basketball-reference.com/awards/aw...
#
# [66 rows x 7 columns]

# %%
## Hala man faghat bayad bazikon haye har fasl ro stats eshoono Scrap konam!

# %%
def scrape_nba_totals(url, season):
    # Send a request to the webpage
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve the page for {season}. Status code: {response.status_code}")
        return

    soup = BeautifulSoup(response.content, "html.parser")

    # Find the table containing player totals
    table = soup.find("table", {"id": "totals_stats"})
    if not table:
        print(f"Table with id 'totals_stats' not found for {season}.")
        return

    # Extract rows from the table
    rows = table.tbody.find_all("tr")
    if not rows:
        print(f"No rows found in the table for {season}.")
        return

    # Initialize an empty list to store player data
    player_data = []

    # Loop through all rows and extract data
    for i, row in enumerate(rows):
        cols = row.find_all("td")
        if cols:  # Skip rows without data
            try:
                player_info = {
                    "Player": cols[0].text.strip(),
                    "Age": cols[1].text.strip(),
                    "Team": cols[2].text.strip(),
                    "Position": cols[3].text.strip(),
                    "Games Played": cols[4].text.strip(),
                    "Games Started": cols[5].text.strip(),
                    "Minutes Played": cols[6].text.strip(),
                    "Field Goals": cols[7].text.strip(),
                    "Field Goal Attempts": cols[8].text.strip(),
                    "Field Goal Percentage": cols[9].text.strip(),
                    "Three Pointers": cols[10].text.strip(),
                    "Three Point Attempts": cols[11].text.strip(),
                    "Three Point Percentage": cols[12].text.strip(),
                    "Two Pointers": cols[13].text.strip(),
                    "Two Point Attempts": cols[14].text.strip(),
                    "Two Point Percentage": cols[15].text.strip(),
                    "Effective Field Goal Percentage": cols[16].text.strip(),
                    "Free Throws": cols[17].text.strip(),
                    "Free Throw Attempts": cols[18].text.strip(),
                    "Free Throw Percentage": cols[19].text.strip(),
                    "Offensive Rebounds": cols[20].text.strip(),
                    "Defensive Rebounds": cols[21].text.strip(),
                    "Total Rebounds": cols[22].text.strip(),
                    "Assists": cols[23].text.strip(),
                    "Steals": cols[24].text.strip(),
                    "Blocks": cols[25].text.strip(),
                    "Turnovers": cols[26].text.strip(),
                    "Personal Fouls": cols[27].text.strip(),
                    "Points": cols[28].text.strip(),
                }
                player_data.append(player_info)
            except IndexError:
                print(f"Skipping row {i + 1} due to missing data for {season}.")

        # Pause for 10 seconds after every 50 players
        if (i + 1) % 50 == 0:
            print(f"Processed {i + 1} players for {season}. Pausing for 10 seconds...")
            time.sleep(10)

    # Convert the list to a DataFrame
    df = pd.DataFrame(player_data)

    if df.empty:
        print(f"No data was extracted from the table for {season}.")
        return

    # Save the DataFrame to a CSV file
    filename = f"nba_totals_{season}.csv"
    df.to_csv(filename, index=False)

    print(f"Data extraction for {season} complete. Saved to '{filename}'.")

# Scrape data for seasons dynamically
base_url = "https://www.basketball-reference.com/leagues/NBA_{}_totals.html"

for year in range(2020, 2025):  # Loop through years 2020 to 2024
    scrape_nba_totals(base_url.format(year), str(year))
